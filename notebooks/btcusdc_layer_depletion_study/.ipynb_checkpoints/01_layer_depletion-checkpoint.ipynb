# %% [markdown]
# # BTCUSDC Layer Depletion Study
#
# This notebook starts the book-layer depletion analysis for Binance BTCUSDC.
#
# Core question:
#
# - given a book state, how long does it take for layer 1, layer 2, ... to disappear?
#
# We will work with replayed book frames and trades, and later separate trade-driven depletion from implied cancellation / replacement pressure.

# %%
from pathlib import Path

import numpy as np
import pandas as pd

from stats.io import load_day
from stats.replay import replay_book_frames
from stats.tables import get_or_build_trades_table

PROJECT_ROOT = Path.cwd().resolve()
for candidate in [PROJECT_ROOT, *PROJECT_ROOT.parents]:
    if (candidate / "stats").is_dir() and (candidate / "notebooks").is_dir():
        PROJECT_ROOT = candidate
        break

DATA_ROOT = PROJECT_ROOT.parent / "exchange-data-recorder" / "data"
SYMBOL = "BTCUSDC"
DAY = "20260223"
DAY_DIR = DATA_ROOT / "binance" / SYMBOL / DAY

dataset = load_day(DAY_DIR)
trades = get_or_build_trades_table(dataset)
book = replay_book_frames(dataset, top_n=5, on_gap="skip-segment")

dataset.day_dir, trades.shape, book.shape

# %% [markdown]
# ## Outline
#
# 1. Define level-k cumulative depth.
# 2. Measure trade-driven depletion times.
# 3. Estimate implied cancellation / replacement as a residual.
# 4. Summarize survival curves by side and level.
# 5. Add diagnostics for censored observations and best-price transitions.
